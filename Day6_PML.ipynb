# %% [markdown]
# <a href="https://colab.research.google.com/github/sujitx-vs/PGCP-AI_PML/blob/main/Day6_PML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/content/univariateStud.csv')

# %%
df
# Out:
#     Hours_Studied  Pass
# 0        3.745401     0
# 1        9.507143     1
# 2        7.319939     1
# 3        5.986585     1
# 4        1.560186     0
# ..            ...   ...
# 95       4.937956     0
# 96       5.227328     1
# 97       4.275410     0
# 98       0.254191     0
# 99       1.078914     0
#
# [100 rows x 2 columns]

# %%
df.describe()
# Out:
#        Hours_Studied    Pass
# count     100.000000  100.00
# mean        4.701807    0.45
# std         2.974894    0.50
# min         0.055221    0.00
# 25%         1.932008    0.00
# 50%         4.641425    0.00
# 75%         7.302031    1.00
# max         9.868869    1.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Hours_Studied  100 non-null    float64
#  1   Pass           100 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 1.7 KB

# %%
sns.distplot(x= df['Hours_Studied'])
# Out:
# /tmp/ipykernel_2831/2181590115.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x= df['Hours_Studied'])
# <Axes: ylabel='Density'>

# %%
x = df.iloc[:,:-1]

# %%
y = df.iloc[:,-1:]

# %%
model = LogisticRegression()
model.fit(x,y)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_pred = model.predict([[3.5]])
print("if 0: fail, 1:Pass : y_pred =",y_pred)
# Out:
# if 0: fail, 1:Pass : y_pred = [0]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
df = pd.read_csv('/content/multivariateStud.csv')


df
# Out:
#         Hours  Attendance  Previous_Score  Pass
# 0    3.745401   94.495953       33.100903     1
# 1    9.507143   54.373713       61.881278     1
# 2    7.319939   48.693692       62.438107     1
# 3    5.986585   69.367166       68.245794     1
# 4    1.560186   99.139027       73.565480     1
# ..        ...         ...             ...   ...
# 145  0.368869   71.334596       86.834915     1
# 146  6.095643   86.199613       89.160064     1
# 147  5.026790   52.949262       75.202691     1
# 148  0.514788   77.373429       52.575575     1
# 149  2.786465   45.120848       35.010043     0
#
# [150 rows x 4 columns]

# %%
x = df.iloc[:,:-1]

# %%
y = df.iloc[:,-1:]

# %%
x
# Out:
#         Hours  Attendance  Previous_Score
# 0    3.745401   94.495953       33.100903
# 1    9.507143   54.373713       61.881278
# 2    7.319939   48.693692       62.438107
# 3    5.986585   69.367166       68.245794
# 4    1.560186   99.139027       73.565480
# ..        ...         ...             ...
# 145  0.368869   71.334596       86.834915
# 146  6.095643   86.199613       89.160064
# 147  5.026790   52.949262       75.202691
# 148  0.514788   77.373429       52.575575
# 149  2.786465   45.120848       35.010043
#
# [150 rows x 3 columns]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.2,random_state=0)

# %%
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_pred =  model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[ 1,  1],
#        [ 1, 27]])

# %%
df = pd.read_csv('/content/Iris (1).csv')

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.nunique()
# Out:
# SepalLengthCm    35
# SepalWidthCm     23
# PetalLengthCm    43
# PetalWidthCm     22
# Species           3
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# # Titianic

# %%
import seaborn as sns
df = sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0           0       3    male  22.0  ...   NaN  Southampton     no  False
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 4           0       3    male  35.0  ...   NaN  Southampton     no   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 886         0       2    male  27.0  ...   NaN  Southampton     no   True
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
# 888         0       3  female   NaN  ...   NaN  Southampton     no  False
# 889         1       1    male  26.0  ...     C    Cherbourg    yes   True
# 890         0       3    male  32.0  ...   NaN   Queenstown     no   True
#
# [891 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.duplicated().sum()
# Out:
# np.int64(107)

# %%
df1 = df.drop_duplicates(keep='last')

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
sns.countplot(data = df , x ='survived')
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(data = df , x ='survived', hue='sex')
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(data = df , x ='survived', hue = 'class')
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(data = df , x ='class', hue ='survived' )
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.distplot(df['age'],kde=True)
# Out:
# /tmp/ipykernel_2831/3732141902.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'],kde=True)
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.histplot(x='age', data= df ,kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.distplot(df['fare'])
# Out:
# /tmp/ipykernel_2831/1195996103.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['fare'])
# <Axes: xlabel='fare', ylabel='Density'>

# %%
sns.barplot(x='embarked', y='fare', data= df)
# Out:
# <Axes: xlabel='embarked', ylabel='fare'>

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df['fare'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['age'].plot(kind="box")
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(df1.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.drop(['sibsp', 'parch','deck'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'fare', 'embarked', 'class', 'who',
#        'adult_male', 'embark_town', 'alive', 'alone'],
#       dtype='object')

# %%
df.drop(['class', 'who','adult_male', 'embark_town', 'alive', 'alone'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'fare', 'embarked'], dtype='object')

# %%
df
# Out:
#      survived  pclass     sex   age     fare embarked
# 0           0       3    male  22.0   7.2500        S
# 1           1       1  female  38.0  71.2833        C
# 2           1       3  female  26.0   7.9250        S
# 3           1       1  female  35.0  53.1000        S
# 4           0       3    male  35.0   8.0500        S
# ..        ...     ...     ...   ...      ...      ...
# 886         0       2    male  27.0  13.0000        S
# 887         1       1  female  19.0  30.0000        S
# 888         0       3  female   NaN  23.4500        S
# 889         1       1    male  26.0  30.0000        C
# 890         0       3    male  32.0   7.7500        Q
#
# [891 rows x 6 columns]

# %%
df.isna().sum()
# Out:
# survived      0
# pclass        0
# sex           0
# age         177
# fare          0
# embarked      2
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy = "median")
df['age'] = imputer.fit_transform(df[['age']])

# %%
df.isna().sum()
# Out:
# survived    0
# pclass      0
# sex         0
# age         0
# fare        0
# embarked    2
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy = "most_frequent")
df['embarked'] = imputer.fit_transform(df[['embarked']]).ravel()

# %%
df.isna().sum()
# Out:
# survived    0
# pclass      0
# sex         0
# age         0
# fare        0
# embarked    0
# dtype: int64

# %%
df
# Out:
#      survived  pclass     sex   age     fare embarked
# 0           0       3    male  22.0   7.2500        S
# 1           1       1  female  38.0  71.2833        C
# 2           1       3  female  26.0   7.9250        S
# 3           1       1  female  35.0  53.1000        S
# 4           0       3    male  35.0   8.0500        S
# ..        ...     ...     ...   ...      ...      ...
# 886         0       2    male  27.0  13.0000        S
# 887         1       1  female  19.0  30.0000        S
# 888         0       3  female  28.0  23.4500        S
# 889         1       1    male  26.0  30.0000        C
# 890         0       3    male  32.0   7.7500        Q
#
# [891 rows x 6 columns]

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
encoder = LabelEncoder()
# onehotencoder = OneHotEncoder()
dummies = pd.get_dummies(df['sex'], drop_first=False)

df = pd.concat([df.drop('sex', axis=1), dummies.astype(int)], axis=1)
# df['sex'] = encoder.fit_transform(df['sex'])
df['embarked'] = encoder.fit_transform(df['embarked'])

# %%
df.nunique()
# Out:
# survived      2
# pclass        3
# age          88
# fare        248
# embarked      3
# female        2
# male          2
# dtype: int64

# %%
df
# Out:
#      survived  pclass   age     fare  embarked  female  male
# 0           0       3  22.0   7.2500         2       0     1
# 1           1       1  38.0  71.2833         0       1     0
# 2           1       3  26.0   7.9250         2       1     0
# 3           1       1  35.0  53.1000         2       1     0
# 4           0       3  35.0   8.0500         2       0     1
# ..        ...     ...   ...      ...       ...     ...   ...
# 886         0       2  27.0  13.0000         2       0     1
# 887         1       1  19.0  30.0000         2       1     0
# 888         0       3  28.0  23.4500         2       1     0
# 889         1       1  26.0  30.0000         0       0     1
# 890         0       3  32.0   7.7500         1       0     1
#
# [891 rows x 7 columns]

# %%
y = df['survived']

# %%
x = df.drop('survived',axis=1)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

lg = LogisticRegression()

# %%
lg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lg.predict(x_test)

# %%
# confusion matrix and accuracy
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[114,  25],
#        [ 28,  56]])

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7623318385650224

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5, metric='minkowski',p=2)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred1 = knn.predict(x_test)

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.820627802690583

# %%
confusion_matrix(y_test,y_pred1)
# Out:
# array([[121,  18],
#        [ 22,  62]])
